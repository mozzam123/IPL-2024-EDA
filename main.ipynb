# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Setting the display precision for floating-point numbers to 2 decimal places
pd.set_option("display.precision", 2)

#Change the default display settings for rows and columns number
pd.set_option("display.max_rows", 400) 
pd.set_option("display.max_columns", 50)

#Retina displays have a much higher pixel density compared to standard displays:
# %config InlineBackend.figure_format = "retina"

# %%
df = pd.read_csv("iplauction2023.csv")

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
# Check column names
df.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
#Check is there are any messing values:
#If the number of non-null entries is less than the total number of rows, it indicates that there are missing values in that column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
#Replace NAN values with 0:
df['base price (in lacs)'] = df['base price (in lacs)'].fillna(0)
df['final price (in lacs)'] = df['final price (in lacs)'].fillna(0)


#Change the column type(from float64 to int64)
df['base price (in lacs)'] = df['base price (in lacs)'].astype("int64")
df['final price (in lacs)'] = df['final price (in lacs)'].astype("int64")

# %%
#Show basic statistical characteristics of each numerical feature
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count                309.00                 309.00
# mean                  28.93                 283.50
# std                   51.13                 423.36
# min                    0.00                   0.00
# 25%                    0.00                  20.00
# 50%                    0.00                  50.00
# 75%                   20.00                 400.00
# max                  200.00                1850.00

# %%
#Show statistical characteristics on non-numerical features
df.describe(include=["object", "bool"])
# Out:
#               name player style nationality franchise    status
# count          309          309         309       238       309
# unique         309            4          14        10         3
# top     Axar Patel       Bowler       India        RR  RETAINED
# freq             1          111         201        25       158

# %%
df['player style'].value_counts()
# Out:
# player style
# Bowler        111
# Allrounder    103
# Batter         55
# WK-Batter      40
# Name: count, dtype: int64

# %%
#Return the relative frequency for each value
df["player style"].value_counts(normalize=True)
# Out:
# player style
# Bowler        0.36
# Allrounder    0.33
# Batter        0.18
# WK-Batter     0.13
# Name: proportion, dtype: float64

# %%
#Sorting the DataFrame df first by the "final price (in lacs)" column in ascending order, and then by the "base price (in lacs)" column in descending order, within the sorted "final price (in lacs)" values.

df.sort_values(by=["final price (in lacs)","base price (in lacs)"], ascending=[True, False]).head()
# Out:
#                       name player style   nationality  base price (in lacs)  \
# 17   Rassie van der Dussen       Batter  South Africa                   200
# 59           Jamie Overton   Allrounder       England                   200
# 87           James Neesham   Allrounder   New Zealand                   200
# 93             Travis Head   Allrounder     Australia                   200
# 141             Adam Milne       Bowler   New Zealand                   200
#
#      final price (in lacs) franchise  status
# 17                       0       NaN  UNSOLD
# 59                       0       NaN  UNSOLD
# 87                       0       NaN  UNSOLD
# 93                       0       NaN  UNSOLD
# 141                      0       NaN  UNSOLD

# %%
df['base price (in lacs)'].mean()
# Out:
# np.float64(28.932038834951456)

# %%
#Gives unique values: table without repetitions
df['base price (in lacs)'].unique()
# Out:
# array([  0,  20,  75, 150, 100,  50, 200,  30,  40])

# %%
#Show the mean of each column for the lines containing 20.0 as base price value
df[df["base price (in lacs)"] == 20.0].select_dtypes(include='number').mean()
# Out:
# base price (in lacs)     20.00
# final price (in lacs)    26.46
# dtype: float64

# %%
#Calculate the mean of a specific column for lines having 20.0 as a base price value
df[df['base price (in lacs)']==20.0]["final price (in lacs)"].mean()
# Out:
# np.float64(26.463414634146343)

# %%
df[(df['base price (in lacs)'] == 20.0 ) & (df['final price (in lacs)'] == 20.0)]['status']
# Out:
# 5      SOLD
# 8      SOLD
# 9      SOLD
# 14     SOLD
# 19     SOLD
# 22     SOLD
# 27     SOLD
# 28     SOLD
# 29     SOLD
# 30     SOLD
# 32     SOLD
# 38     SOLD
# 39     SOLD
# 40     SOLD
# 48     SOLD
# 53     SOLD
# 54     SOLD
# 60     SOLD
# 65     SOLD
# 66     SOLD
# 68     SOLD
# 72     SOLD
# 73     SOLD
# 75     SOLD
# 98     SOLD
# 113    SOLD
# 120    SOLD
# 124    SOLD
# Name: status, dtype: object

# %%
df.loc[0:6, "name": "franchise"]
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                     0
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
# 5     Abdul Basith   Allrounder         India                    20
# 6  Prashant Chopra   Allrounder         India                    20
#
#    final price (in lacs) franchise
# 0                     20       KKR
# 1                      0       NaN
# 2                      0       NaN
# 3                    150       KKR
# 4                    100        RR
# 5                     20        RR
# 6                      0       NaN

# %%
df.iloc[0:5, 0:4]
# Out:
#               name player style   nationality  base price (in lacs)
# 0     Harshit Rana       Bowler         India                     0
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100

# %% [markdown]
# ##### To apply functions to each column or each row; we use apply()

# %%
#Apply the max function on numerical columns!
df.select_dtypes(include = 'number').apply(np.max)
# Out:
# base price (in lacs)      200
# final price (in lacs)    1850
# dtype: int64

# %%
df[df['name'].apply(lambda name: name[0] == 'A')]
# Out:
#                             name player style   nationality  \
# 5                   Abdul Basith   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# 22              Anmolpreet Singh       Batter         India
# 23                    Adam Zampa       Bowler     Australia
# 39             Ajay Jadav Mandal   Allrounder         India
# 47                 Avinash Singh       Bowler         India
# 79                   Amit Mishra       Bowler         India
# 117           Abhimanyu Easwaran    WK-Batter         India
# 130               Ajinkya Rahane       Batter         India
# 139                  Adil Rashid       Bowler       England
# 141                   Adam Milne       Bowler   New Zealand
# 157                Akash Madhwal       Bowler         India
# 161  Abhinav Manohar Sadarangani       Batter         India
# 168                Atharva Taide   Allrounder         India
# 180              Abhishek Sharma   Allrounder         India
# 182                   Anuj Rawat    WK-Batter         India
# 194                   Avesh Khan       Bowler         India
# 198                 Ayush Badoni   Allrounder         India
# 202               Alzarri Joseph       Bowler   West Indies
# 222                   Anukul Roy   Allrounder         India
# 228                Ambati Rayudu    WK-Batter         India
# 260                Aiden Markram       Batter  South Africa
# 262              Arjun Tendulkar   Allrounder         India
# 278                  Abdul Samad   Allrounder         India
# 286               Arshdeep Singh       Bowler         India
# 289                   Akash Deep       Bowler         India
# 298                Andre Russell   Allrounder   West Indies
# 302                Anrich Nortje       Bowler  South Africa
# 308                   Axar Patel   Allrounder         India
#
#      base price (in lacs)  final price (in lacs) franchise    status
# 5                      20                     20        RR      SOLD
# 7                     100                    100       SRH      SOLD
# 13                     20                      0       NaN    UNSOLD
# 14                     20                     20        RR      SOLD
# 22                     20                     20       SRH      SOLD
# 23                    150                    150        RR      SOLD
# 39                     20                     20       CSK      SOLD
# 47                     20                     60       RCB      SOLD
# 79                     50                     50       LSG      SOLD
# 117                    20                      0       NaN    UNSOLD
# 130                    50                     50       CSK      SOLD
# 139                   200                    200       SRH      SOLD
# 141                   200                      0       NaN    UNSOLD
# 157                     0                     20        MI  RETAINED
# 161                     0                    260        GT  RETAINED
# 168                     0                     20      PBKS  RETAINED
# 180                     0                    650       SRH  RETAINED
# 182                     0                    340       RCB  RETAINED
# 194                     0                   1000       LSG  RETAINED
# 198                     0                     20       LSG  RETAINED
# 202                     0                    240        GT  RETAINED
# 222                     0                     20       KKR  RETAINED
# 228                     0                    675       CSK  RETAINED
# 260                     0                    260       SRH  RETAINED
# 262                     0                     30        MI  RETAINED
# 278                     0                    400       SRH  RETAINED
# 286                     0                    400      PBKS  RETAINED
# 289                     0                     20       RCB  RETAINED
# 298                     0                   1200       KKR  RETAINED
# 302                     0                    650        DC  RETAINED
# 308                     0                    900        DC  RETAINED

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                     0
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
#
#    final price (in lacs) franchise    status
# 0                     20       KKR  RETAINED
# 1                      0       NaN    UNSOLD
# 2                      0       NaN    UNSOLD
# 3                    150       KKR      SOLD
# 4                    100        RR      SOLD

# %% [markdown]
# ##### The map method can be used to replace values in a column by passing a dictionary of the form {old_value: new_value] as its argument

# %%
d = {"SOLD": "Purshased", "UNSOLD": "Unpurshased"}
df['status'] = df['status'].map(d)
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                     0
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
#
#    final price (in lacs) franchise       status
# 0                     20       KKR          NaN
# 1                      0       NaN  Unpurshased
# 2                      0       NaN  Unpurshased
# 3                    150       KKR    Purshased
# 4                    100        RR    Purshased

# %%
#We can do the same with replace method:
df = df.replace({"status": d})
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                     0
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
#
#    final price (in lacs) franchise       status
# 0                     20       KKR          NaN
# 1                      0       NaN  Unpurshased
# 2                      0       NaN  Unpurshased
# 3                    150       KKR    Purshased
# 4                    100        RR    Purshased
